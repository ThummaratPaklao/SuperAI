# %%
import pandas as pd

# %%
# !pip install --upgrade --no-cache-dir gdown
# https://drive.google.com/file/d/11U1sLTSXSSZQAdQsPHfZnkSKdc8j7qmH/view?usp=sharing
# !gdown --id 11U1sLTSXSSZQAdQsPHfZnkSKdc8j7qmH
# !unzip '/content/Official_Dataset-20220307T100948Z-001.zip'
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14774 sha256=e614de1a807ab0dbb3add6cff28f3318c51697490538755578b8ce8c22d7023f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3rw38hkp/wheels/fb/c3/0e/c4d8ff8bfcb0461afff199471449f642179b74968c15b7a69c
# Successfully built gdown
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.2.2
#     Uninstalling gdown-4.2.2:
#       Successfully uninstalled gdown-4.2.2
# ...
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=11U1sLTSXSSZQAdQsPHfZnkSKdc8j7qmH
# To: /content/Official_Dataset-20220307T100948Z-001.zip
# ...

# %%
df1=pd.read_csv("/content/drive/MyDrive/nlp_translate/tatoeba.csv")

# %%
df1
# Out:
#                                                EN_data  \
# 0                                 Let's try something.
# 1                                 Let's try something.
# 2                                 Let's try something.
# 3                               I have to go to sleep.
# 4     Today is June 18th and it is Muiriel's birthday!
# ...                                                ...
# 1080  I'm looking for someone to do my laundry for me.
# 1081                                       What a day!
# 1082                                      Flip a coin.
# 1083                                      It's a date.
# 1084                                      It's a sign.
#
#                                                 TH_data
# 0                                              ลองทำดู!
# 1                                  มาลองบางอย่างกันเถอะ
# 2                                  ลองทำอะไรสักอย่างกัน
# 3                                      ฉันต้องไปนอนแล้ว
# ...

# %%
df15=pd.read_csv("/content/drive/MyDrive/nlp_translate/Top_clear_enginTH.csv",encoding='thai')
df15 = df15.rename(columns = {'EN':'EN_data','TH':'TH_data'})

# %%
df2 = pd.read_csv("/content/drive/MyDrive/nlp_translate/QED.csv")

# %%
# !unzip /content/drive/MyDrive/nlp_translate/scb.zip
# Out:
# Archive:  /content/drive/MyDrive/nlp_translate/scb.zip
#   inflating: task_master_1.csv
#   inflating: thai_websites.csv
#   inflating: wikipedia.csv
#   inflating: generated_reviews_translator.csv
#   inflating: generated_reviews_yn.csv
#   inflating: mozilla_common_voice.csv
#   inflating: msr_paraphrase.csv
#   inflating: nus_sms.csv
#   inflating: paracrawl.csv
#   inflating: apdf.csv
#   inflating: assorted_government.csv
#   inflating: generated_reviews_crowd.csv

# %%
# !pip install transformers
# !pip install datasets
# !pip install sentencepiece
# Out:
# ...
#      |████████████████████████████████| 3.8 MB 7.8 MB/s
# ...
#      |████████████████████████████████| 895 kB 58.4 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 57.7 MB/s
# ...
#      |████████████████████████████████| 596 kB 85.4 MB/s
# ...
#      |████████████████████████████████| 67 kB 6.6 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
#      |████████████████████████████████| 312 kB 9.5 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 78.9 MB/s
# ...
#      |████████████████████████████████| 212 kB 92.9 MB/s
# ...
#      |████████████████████████████████| 134 kB 86.5 MB/s
# ...
#      |████████████████████████████████| 127 kB 77.8 MB/s
# ...
#      |████████████████████████████████| 144 kB 77.4 MB/s
# ...
#      |████████████████████████████████| 271 kB 87.7 MB/s
# ...
#      |████████████████████████████████| 94 kB 4.4 MB/s
# ...
#   Attempting uninstall: urllib3
# ...

# %%
df3=pd.read_csv('/content/apdf.csv')
df3 = df3.rename(columns = {'en_text':'EN_data','th_text':'TH_data'})

# %%
df4=pd.read_csv('/content/assorted_government.csv')
df4 = df4.rename(columns = {'en_text':'EN_data','th_text':'TH_data'})

# %%
df5=pd.read_csv('/content/generated_reviews_crowd.csv')
df5 = df5.rename(columns = {'en_text':'EN_data','th_text':'TH_data'})

# %%
df6=pd.read_csv('/content/generated_reviews_translator.csv')
df6 = df6.rename(columns = {'en_text':'EN_data','th_text':'TH_data'})

# %%
df6
# Out:
#                                                   EN_data  \
# 0       These are a terrible product from China.The li...
# 1       They can't be used for anything other than par...
# 2       And yes, I followed directions exactly as they...
# 3       What kind of trash can cannot survive simple h...
# 4                                     I'm returning them.
# ...                                                   ...
# 133325  The songs are well known and the sound quality...
# 133326  I think it might be more important these days ...
# 133327          If that's not what you want, buy this CD.
# 133328  It brings me back 20 years when we used to lis...
# 133329  My friends can't stop asking where they can bu...
#
#                                                   TH_data
# 0       สินค้าพวกนี้เป็นสินค้าห่วยๆที่มาจากประเทศจีน ท...
# 1        ไม่สามารถใช้ทำอะไรได้มากกว่าใช้ประดับในงานเลี้ยง
# 2       และแน่นอนว่าฉันได้ทำตามแนวทางที่เขาเขียนไว้อย่...
# ...

# %%
df7=pd.read_csv('/content/generated_reviews_yn.csv')
df7 = df7.rename(columns = {'en_text':'EN_data','th_text':'TH_data'})

# %%
df8=pd.read_csv('/content/mozilla_common_voice.csv')
df8 = df8.rename(columns = {'en_text':'EN_data','th_text':'TH_data'})

# %%
df9=pd.read_csv('/content/msr_paraphrase.csv')
df9 = df9.rename(columns = {'en_text':'EN_data','th_text':'TH_data'})

# %%
df

# %%
df10=pd.read_csv('/content/nus_sms.csv')
df10 = df10.rename(columns = {'en_text':'EN_data','th_text':'TH_data'})

# %%
df11=pd.read_csv('/content/task_master_1.csv')
df11 = df11.rename(columns = {'en_text':'EN_data','th_text':'TH_data'})

# %%
df12=pd.read_csv('/content/paracrawl.csv')
df12 = df12.rename(columns = {'en_text':'EN_data','th_text':'TH_data'})

# %%
df13=pd.read_csv('/content/thai_websites.csv')
df13 = df13.rename(columns = {'en_text':'EN_data','th_text':'TH_data'})

# %%
df14=pd.read_csv('/content/wikipedia.csv')
df14 = df14.rename(columns = {'en_text':'EN_data','th_text':'TH_data'})

# %%
df=pd.DataFrame()

# %%
df= pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15],ignore_index=True)

# %%
df= pd.concat([df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14],ignore_index=True)

# %%
df= pd.concat([df3,df4,df6,df8,df10,df11,df12,df14],ignore_index=True)

# %%
df
# Out:
#                                                    EN_data  \
# 0                                     Let's try something.
# 1                                     Let's try something.
# 2                                     Let's try something.
# 3                                   I have to go to sleep.
# 4         Today is June 18th and it is Muiriel's birthday!
# ...                                                    ...
# 1681720  When Wijai talked to me on the phone his voice...
# 1681721  The bus terminal is on the West side of the city.
# 1681722                                        Encapsulate
# 1681723      Death Frightens me specifically my own death.
# 1681724                           I weigh sixty kilograms.
#
#                                                    TH_data
# 0                                                 ลองทำดู!
# 1                                     มาลองบางอย่างกันเถอะ
# 2                                     ลองทำอะไรสักอย่างกัน
# ...

# %%
Eng_valdata=[]

file1 = open('/content/Official_Dataset/ValidationSet/Valid1+2/dev.en','r')
Lines = file1.readlines()

for line in Lines:
  Eng_valdata.append(line.rstrip("\n"))

file2 = open('/content/Official_Dataset/ValidationSet/Valid1+2/dev2.en','r')
Lines2 = file2.readlines()
for line in Lines2:
  Eng_valdata.append(line.rstrip("\n"))

# %%
Th_valdata=[]

file3 = open('/content/Official_Dataset/ValidationSet/Valid1+2/dev.th','r')
Lines3 = file3.readlines()

for line in Lines3:
  Th_valdata.append(line.rstrip("\n"))

file4 = open('/content/Official_Dataset/ValidationSet/Valid1+2/dev2.th','r')
Lines4 = file4.readlines()
for line in Lines4:
  Th_valdata.append(line.rstrip("\n"))

# %%
valdata = {'EN_data':Eng_valdata,'TH_data':Th_valdata}
val_df=pd.DataFrame(valdata)

# %%
val_df
# Out:
#                                                 EN_data  \
# 0     It has been confirmed that eight thoroughbred ...
# 1     Randwick has been locked down, and is expected...
# 2     It is expected that the virulent flu will affe...
# 3     NSW Minister for Primary Industries said the f...
# 4     The cases are the first infections of race hor...
# ...                                                 ...
# 3013                       I wonder where she got this.
# 3014                            We must close the gate.
# 3015                You said I was free to come and go.
# 3016                   Well, we're on pins and needles.
# 3017      Kjetil, we have to get up. We have to get up.
#
#                                                 TH_data
# 0     ได้ เป็น ที่ ยืนยัน แน่นอน แล้ว ว่า ม้า แข่ง พ...
# 1     สนาม แข่ง ม้า แร ็นด์ วิค ถูก ปิด และ คาด ว่า ...
# 2     คาด ว่า ไข้ หวัด ใหญ่ ร้ายแรง นี้ จะ กระทบ ต่อ...
# 3     รัฐมนตรี อุตสาหกรรม พื้นฐาน นอง รัฐNSW กล่าว ว...
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %%
tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-th-en")
# Out:
# Downloading:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/791k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.29M [00:00<?, ?B/s]

# %%
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-th-en")
# Out:
# Downloading:   0%|          | 0.00/292M [00:00<?, ?B/s]

# %%
# !pip install datasets

# %%
import datasets

# %%
data=datasets.DatasetDict()

# %%
dictn=dict()
dictn['th']=df["TH_data"]
dictn['en']=df["EN_data"]

# %%
import pyarrow as pa
tab_dat2=pa.Table.from_pydict(dictn)

# %%
data["train"]=datasets.Dataset(tab_dat2)

# %%
data["train"][100]
# Out:
# {'en': 'How the law will impact foreign NGOs in practice depends on how it is implemented and remains to be tested, experts say. It will take effect the beginning of January 2017.',
#  'th': 'กฎหมายดังกล่าวจะส่งผลกระทบต่อองค์กรพัฒนาเอกชนของต่างประเทศในทางปฏิบัติอย่างไรนั้น ขึ้นอยู่กับวิธีการนำกฎหมายไปใช้ซึ่งยังต้องรอการพิสูจน์ต่อไป ผู้เชี่ยวชาญกล่าว โดยกฎหมายจะมีผลบังคับใช้ในต้นเดือนมกราคม พ.ศ. 2560'}

# %%
dictn1=dict()
dictn1['th']=val_df["TH_data"]
dictn1['en']=val_df["EN_data"]

# %%
tab_dat22=pa.Table.from_pydict(dictn1)

# %%
data["test"]=datasets.Dataset(tab_dat22)

# %%
dd = datasets.DatasetDict({"train":data["train"],"test":data["test"]})

# %%
dd
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['th', 'en'],
#         num_rows: 1681725
#     })
#     test: Dataset({
#         features: ['th', 'en'],
#         num_rows: 3018
#     })
# })

# %%
source_lang = "en"
target_lang = "th"

def preprocess_function(examples):
    inputs = examples[source_lang]
    targets = examples[target_lang]

    model_inputs = tokenizer(inputs, max_length=128, truncation=True)

    with tokenizer.as_target_tokenizer():
        labels = tokenizer(targets, max_length=128, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
from transformers import AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer, AutoTokenizer

model_checkpoint = "Helsinki-NLP/opus-mt-en-mul"

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
tokenizer.source_lang = "en"
tokenizer.target_lang = "th"

tokenized_books = dd.map(preprocess_function, batched=True)
model = AutoModelForSeq2SeqLM.from_pretrained(model_checkpoint)
data_collator = DataCollatorForSeq2Seq(tokenizer, model, return_tensors = 'pt')
# Out:
# Downloading:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/690k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.35M [00:00<?, ?B/s]
# ...
#   0%|          | 0/4 [00:00<?, ?ba/s]
# Downloading:   0%|          | 0.00/296M [00:00<?, ?B/s]

# %%
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

# %%
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)

# %%
from google.colab import drive
import os

# Create using folder in Model Generate.
directoryName = 'TranslateWK7'

try:
    os.mkdir(directoryName)
except:
    print('Already Created!')

# %%
# !pip install sacrebleu
# Out:
# ...
#      |████████████████████████████████| 90 kB 5.2 MB/s
# ...

# %%
from datasets import load_metric
import numpy as np
metric = load_metric("sacrebleu")


def compute_metrics(eval_preds):
    preds, labels = eval_preds
    # In case the model returns more than the prediction logits
    if isinstance(preds, tuple):
        preds = preds[0]

    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)

    # Replace -100s in the labels as we can't decode them
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Some simple post-processing
    decoded_preds = [pred.strip() for pred in decoded_preds]
    decoded_labels = [[label.strip()] for label in decoded_labels]

    result = metric.compute(predictions=decoded_preds, references=decoded_labels)
    return {"bleu": result["score"]}
# Out:
# Downloading:   0%|          | 0.00/2.36k [00:00<?, ?B/s]

# %%
batch_size = 16
args = Seq2SeqTrainingArguments(
    output_dir=directoryName,
    evaluation_strategy = "epoch",
    learning_rate=1e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    weight_decay=0.01,
    save_total_limit=2,
    num_train_epochs=5,
    predict_with_generate=True
)

# %%
trainer = Seq2SeqTrainer(
    model,
    args,
    train_dataset=tokenized_books["train"],
    eval_dataset=tokenized_books["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

# %%
# check score before train
trainer.evaluate(max_length=128)
# Out:
# The following columns in the evaluation set  don't have a corresponding argument in `MarianMTModel.forward` and have been ignored: en, th. If en, th are not expected by `MarianMTModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 3018
#   Batch size = 16
#     <div>
#
#       <progress value='189' max='189' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [189/189 04:37]
#     </div>
# {'eval_bleu': 0.6419291379957784,
#  'eval_loss': 7.563409805297852,
#  'eval_runtime': 289.9916,
#  'eval_samples_per_second': 10.407,
#  'eval_steps_per_second': 0.652}

# %%
trainer.train()
# Out:
# The following columns in the training set  don't have a corresponding argument in `MarianMTModel.forward` and have been ignored: th, en. If th, en are not expected by `MarianMTModel.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 1681725
#   Num Epochs = 5
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 525540
#     <div>
#
#       <progress value='37442' max='525540' style='width:300px; height:20px; vertical-align: middle;'></progress>
# ...

# %%
# check score before train
trainer.evaluate(max_length=128)
# Out:
# The following columns in the evaluation set  don't have a corresponding argument in `MarianMTModel.forward` and have been ignored: th, en. If th, en are not expected by `MarianMTModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 3018
#   Batch size = 16
#     <div>
#
#       <progress value='214730' max='525540' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [214730/525540 11:40:49 < 16:54:25, 5.11 it/s, Epoch 2.04/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.066500</td>
#       <td>1.831188</td>
#       <td>2.126058</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.972200</td>
#       <td>1.787076</td>
#       <td>2.178042</td>
#     </tr>
# ...

# %%
import os
import zipfile

def zipdir(path, ziph):
    # ziph is zipfile handle
    for root, dirs, files in os.walk(path):
        for file in files:
            ziph.write(os.path.join(root, file),
                       os.path.relpath(os.path.join(root, file),
                                       os.path.join(path, '..')))

zipf = zipfile.ZipFile('/content/drive/MyDrive/nlp_translate/Python.zip', 'w', zipfile.ZIP_DEFLATED)
zipdir('/content/TranslateWK7/', zipf)
zipf.close()

# %%
# !unzip /content/Python.zip
# Out:
# Archive:  /content/Python.zip
#   inflating: checkpoint-214500/config.json
#   inflating: checkpoint-214500/rng_state.pth
#   inflating: checkpoint-214500/target.spm
#   inflating: checkpoint-214500/vocab.json
#   inflating: checkpoint-214500/trainer_state.json
#   inflating: checkpoint-214500/tokenizer_config.json
#   inflating: checkpoint-214500/pytorch_model.bin
#   inflating: checkpoint-214500/source.spm
#   inflating: checkpoint-214500/special_tokens_map.json
#   inflating: checkpoint-214500/optimizer.pt
#   inflating: checkpoint-214500/scheduler.pt
#   inflating: checkpoint-214500/training_args.bin
